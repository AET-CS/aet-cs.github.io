# %%
# Scratch Heap Map

# %%
import matplotlib.pyplot as plt

# %%
rx = [-150,-75,-74,0,1,75,76,150]
ry = [0,0,0,255,255,255,255,255]
gy = [0,255,255,255,255,255,255,0]
by = [255,255,255,255,255,0,0,0]

# %%
plt.plot(x,gy, color="green")
plt.plot(x,ry, color="red")
plt.plot(x,by, color="blue")
plt.grid(which = 'both')
plt.xlabel("Temperature")
plt.ylabel("RGB Value")
# Out:
# Text(0, 0.5, 'RGB Value')
