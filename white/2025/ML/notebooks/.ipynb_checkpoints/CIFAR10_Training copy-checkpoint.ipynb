# %% [markdown]
# # Training CiFAR with Keras
#
# This simple example demonstrates how to plug TensorFlow Datasets (TFDS) into a Keras model.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from matplotlib import pyplot as plt

# %% [markdown]
# ## Imports and setup
# We use `tensorflow` for modeling and `tensorflow_datasets` (TFDS) for convenient dataset loading + metadata. Make sure the notebook kernel points to the environment where TensorFlow is installed.

# %% [markdown]
# ## Step 1: Create your input pipeline
#
# Start by building an efficient input pipeline using advices from:
# * The [Performance tips](https://www.tensorflow.org/datasets/performances) guide
# * The [Better performance with the `tf.data` API](https://www.tensorflow.org/guide/data_performance#optimize_performance) guide

# %% [markdown]
# ### Load a dataset
#
# Load the MNIST dataset with the following arguments:
#
# * `shuffle_files=True`: The MNIST data is only stored in a single file, but for larger datasets with multiple files on disk, it's good practice to shuffle them when training.
# * `as_supervised=True`: Returns a tuple `(img, label)` instead of a dictionary `{'image': img, 'label': label}`.

# %%
(ods_train, ods_test), ds_info = tfds.load(
    'cifar10',
    split=['train', 'test'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)
# Out:
# 2026-02-24 12:44:16.471183: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4
# 2026-02-24 12:44:16.471213: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 24.00 GB
# 2026-02-24 12:44:16.471220: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 8.00 GB
# 2026-02-24 12:44:16.471452: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2026-02-24 12:44:16.471461: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %% [markdown]
# ### Dataset info
# `ds_info` includes split sizes, feature shapes, and class labels. We’ll use it later for class names and sanity checks.

# %% [markdown]
# ### Build a training pipeline
#
# Apply the following transformations:
#
# * `tf.data.Dataset.map`: TFDS provide images of type `tf.uint8`, while the model expects `tf.float32` in the range [0,1]. Therefore, you need to normalize images.
# * `tf.data.Dataset.cache` As you fit the dataset in memory, cache it before shuffling for a better performance.<br/>
# __Note:__ Random transformations should be applied after caching.
# * `tf.data.Dataset.shuffle`: For true randomness, set the shuffle buffer to the full dataset size.<br/>
# __Note:__ For large datasets that can't fit in memory, use `buffer_size=1000` if your system allows it.
# * `tf.data.Dataset.batch`: Batch elements of the dataset after shuffling to get unique batches at each epoch. You can increase the batch size to speed up training, depending on the amount of GPU memory.
# * `tf.data.Dataset.prefetch`: It is good practice to end the pipeline by prefetching [for performance](https://www.tensorflow.org/guide/data_performance#prefetching).

# %%
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  return tf.cast(image, tf.float32) / 255., label # type: ignore

ds_train = ods_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(512)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ### Why these pipeline steps?
# - **Normalize** to scale pixels to $[0,1]$ for stable training.
# - **Cache** to avoid repeated disk reads.
# - **Shuffle** for better randomness each epoch.
# - **Batch** to leverage vectorization on GPU.
# - **Prefetch** to overlap data loading with model execution.

# %% [markdown]
# ## EDA

# %% [markdown]
# Look at some sample images. Note the way we get the class names from the ds_info dataset and use an iterator to get data from the training set in one batch.

# %%
# Display a sample of images from the training set with their labels
class_names = ds_info.features['label'].names

# Take a batch of images and labels
sample_images, sample_labels = next(iter(ods_train.batch(16)))

# Create a plot
plt.figure(figsize=(12, 8))
for i in range(16):
    plt.subplot(4, 4, i + 1)
    plt.imshow(sample_images[i].numpy())
    plt.title(class_names[sample_labels[i].numpy()])
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# 2026-02-24 12:44:24.785919: W tensorflow/core/kernels/data/cache_dataset_ops.cc:858] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# Use EDA to confirm shapes, class balance, and a few example images before training. This helps catch preprocessing bugs early.

# %% [markdown]
# ### Build an evaluation pipeline
#
# Your testing pipeline is similar to the training pipeline with small differences:
#
#  * You don't need to call `tf.data.Dataset.shuffle`.
#  * Caching is done after batching because batches can be the same between epochs.

# %%
ds_test = ods_test.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Step 2: Create and train the model
#
# Plug the TFDS input pipeline into a simple Keras model, compile the model, and train it.

# %% [markdown]
# ### Baseline model
# Start simple: a flattened input and a few dense layers. This sets a reference point before adding regularization or augmentation.

# %%
# Create the Model
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(), # turn the 2D images each into one vector
  tf.keras.layers.Dense(128, activation='leaky_relu'), # a layer with 128 nodes
  tf.keras.layers.Dense(10) # the final layer, one node for each class
])

# Compile the Model
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001), # how exactly does gradient descent take a step and what is the step size
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), # the correct loss function for categorical data
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()], # report accuracy while training
)

# Run the model. Save history for further analysis
history = model.fit(
    ds_train, # the training set
    epochs=30, # number of epochs (full pass through entire training set)
    validation_data=ds_test, # the test set to use while training
)
# Out:
# Epoch 1/30
# 2026-02-24 12:44:43.497750: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.1173 - sparse_categorical_accuracy: 0.2716 - val_loss: 1.8716 - val_sparse_categorical_accuracy: 0.3278
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8347 - sparse_categorical_accuracy: 0.3515 - val_loss: 1.7984 - val_sparse_categorical_accuracy: 0.3656
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7772 - sparse_categorical_accuracy: 0.3775 - val_loss: 1.7538 - val_sparse_categorical_accuracy: 0.3800
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7306 - sparse_categorical_accuracy: 0.3966 - val_loss: 1.7234 - val_sparse_categorical_accuracy: 0.3971
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6922 - sparse_categorical_accuracy: 0.4105 - val_loss: 1.6911 - val_sparse_categorical_accuracy: 0.4069
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6524 - sparse_categorical_accuracy: 0.4218 - val_loss: 1.6525 - val_sparse_categorical_accuracy: 0.4230
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6299 - sparse_categorical_accuracy: 0.4294 - val_loss: 1.6318 - val_sparse_categorical_accuracy: 0.4201
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6031 - sparse_categorical_accuracy: 0.4379 - val_loss: 1.6597 - val_sparse_categorical_accuracy: 0.4182
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5868 - sparse_categorical_accuracy: 0.4476 - val_loss: 1.6188 - val_sparse_categorical_accuracy: 0.4386
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5703 - sparse_categorical_accuracy: 0.4506 - val_loss: 1.5806 - val_sparse_categorical_accuracy: 0.4495
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5601 - sparse_categorical_accuracy: 0.4550 - val_loss: 1.5872 - val_sparse_categorical_accuracy: 0.4434
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5410 - sparse_categorical_accuracy: 0.4622 - val_loss: 1.5875 - val_sparse_categorical_accuracy: 0.4376
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5328 - sparse_categorical_accuracy: 0.4628 - val_loss: 1.5740 - val_sparse_categorical_accuracy: 0.4494
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5225 - sparse_categorical_accuracy: 0.4669 - val_loss: 1.5463 - val_sparse_categorical_accuracy: 0.4604
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4998 - sparse_categorical_accuracy: 0.4763 - val_loss: 1.5478 - val_sparse_categorical_accuracy: 0.4572
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4804 - sparse_categorical_accuracy: 0.4828 - val_loss: 1.5370 - val_sparse_categorical_accuracy: 0.4628
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4763 - sparse_categorical_accuracy: 0.4855 - val_loss: 1.5329 - val_sparse_categorical_accuracy: 0.4560
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4686 - sparse_categorical_accuracy: 0.4852 - val_loss: 1.5123 - val_sparse_categorical_accuracy: 0.4665
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4631 - sparse_categorical_accuracy: 0.4878 - val_loss: 1.5322 - val_sparse_categorical_accuracy: 0.4505
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4511 - sparse_categorical_accuracy: 0.4913 - val_loss: 1.4969 - val_sparse_categorical_accuracy: 0.4792
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4324 - sparse_categorical_accuracy: 0.4991 - val_loss: 1.4880 - val_sparse_categorical_accuracy: 0.4754
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4342 - sparse_categorical_accuracy: 0.4989 - val_loss: 1.4978 - val_sparse_categorical_accuracy: 0.4714
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4293 - sparse_categorical_accuracy: 0.4990 - val_loss: 1.5207 - val_sparse_categorical_accuracy: 0.4602
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4158 - sparse_categorical_accuracy: 0.5035 - val_loss: 1.5325 - val_sparse_categorical_accuracy: 0.4632
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3974 - sparse_categorical_accuracy: 0.5110 - val_loss: 1.5374 - val_sparse_categorical_accuracy: 0.4527
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4163 - sparse_categorical_accuracy: 0.5032 - val_loss: 1.5164 - val_sparse_categorical_accuracy: 0.4601
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3961 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.5086 - val_sparse_categorical_accuracy: 0.4697
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3852 - sparse_categorical_accuracy: 0.5163 - val_loss: 1.4755 - val_sparse_categorical_accuracy: 0.4806
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3695 - sparse_categorical_accuracy: 0.5197 - val_loss: 1.5568 - val_sparse_categorical_accuracy: 0.4520
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3701 - sparse_categorical_accuracy: 0.5190 - val_loss: 1.4745 - val_sparse_categorical_accuracy: 0.4845

# %% [markdown]
# Define a function to show the training curves using the history from a training session

# %%
import matplotlib.pyplot as plt

def show_training_curves(history):
  acc = history.history['sparse_categorical_accuracy']
  val_acc = history.history['val_sparse_categorical_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(len(acc))

  plt.figure(figsize=(12, 4))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.grid(True)

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.grid(True)

  plt.tight_layout()
  plt.show()

# %% [markdown]
# Let's see the training run. Validation accuracy is still increasing a bit, so we'll end up training some more

# %%
show_training_curves(history)

# %% [markdown]
# Because the model seems to be learning still, add 10 more epochs. If you *don't recompile*, then the model starts up where it left off. We do have to manually merge the two histories.

# %%
new_history = model.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test,
)

for key in new_history.history:
    history.history[key].extend(new_history.history[key])
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3108 - sparse_categorical_accuracy: 0.5405 - val_loss: 1.4487 - val_sparse_categorical_accuracy: 0.4902
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3080 - sparse_categorical_accuracy: 0.5381 - val_loss: 1.4852 - val_sparse_categorical_accuracy: 0.4750
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3061 - sparse_categorical_accuracy: 0.5407 - val_loss: 1.4466 - val_sparse_categorical_accuracy: 0.4868
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2965 - sparse_categorical_accuracy: 0.5457 - val_loss: 1.4608 - val_sparse_categorical_accuracy: 0.4797
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2948 - sparse_categorical_accuracy: 0.5438 - val_loss: 1.4413 - val_sparse_categorical_accuracy: 0.4920
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2862 - sparse_categorical_accuracy: 0.5504 - val_loss: 1.4517 - val_sparse_categorical_accuracy: 0.4900
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2864 - sparse_categorical_accuracy: 0.5466 - val_loss: 1.4696 - val_sparse_categorical_accuracy: 0.4789
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2704 - sparse_categorical_accuracy: 0.5542 - val_loss: 1.4567 - val_sparse_categorical_accuracy: 0.4867
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2802 - sparse_categorical_accuracy: 0.5502 - val_loss: 1.4583 - val_sparse_categorical_accuracy: 0.4826
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2661 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.4338 - val_sparse_categorical_accuracy: 0.4963

# %%
show_training_curves(history)

# %% [markdown]
# Let's create a confusion matrix plotting function and run it. Pay attention to the "predictions" logic!!

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def show_confusion_matrix(model, dataset, info):
  # Get true labels from dataset
  true_labels = []
  for images, labels in dataset.unbatch():
      true_labels.append(labels.numpy())
  true_labels = np.array(true_labels)

  # Predict probabilities for the test set
  predictions = model.predict(dataset)

  # Get predicted classes
  predicted_labels = np.argmax(predictions, axis=1) ## VERY IMPORTANT. How you get a class label out of a neural network.

  # Generate the confusion matrix
  cm = confusion_matrix(true_labels, predicted_labels)

  # Get class names from dataset info (assuming cifar10 has 'label' feature with names)
  class_names = info.features['label'].names

  # Plot the confusion matrix
  plt.figure(figsize=(10, 8))
  sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=class_names, yticklabels=class_names)
  plt.xlabel('Predicted Labels')
  plt.ylabel('True Labels')
  plt.title('Confusion Matrix')
  plt.show()

# %%
show_confusion_matrix(model, ds_test, ds_info)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2026-02-18 15:22:43.310568: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# ## Improve

# %% [markdown]
# ### Improving the baseline
# We gradually add **BatchNorm**, **Dropout**, and **L2 regularization** to improve generalization. We also experiment with a smaller learning rate to stabilize training.

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(
            filters=6, kernel_size=5, activation="sigmoid", padding="same"
        ),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Conv2D(filters=16, kernel_size=5, activation="sigmoid"),
        tf.keras.layers.AvgPool2D(pool_size=2, strides=2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(120, activation="sigmoid"),
        tf.keras.layers.Dense(84, activation="sigmoid"),
        tf.keras.layers.Dense(10),
    ]
)

# No need to call .adapt() for BatchNormalization as it learns stats per batch

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)


history = model.fit(
    ds_train,
    epochs=60,
    validation_data=ds_test,
)
# Out:
# Epoch 1/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.3119 - sparse_categorical_accuracy: 0.1002 - val_loss: 2.3017 - val_sparse_categorical_accuracy: 0.1525
# Epoch 2/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.1795 - sparse_categorical_accuracy: 0.1860 - val_loss: 2.0381 - val_sparse_categorical_accuracy: 0.2400
# Epoch 3/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.0050 - sparse_categorical_accuracy: 0.2558 - val_loss: 1.9590 - val_sparse_categorical_accuracy: 0.2798
# Epoch 4/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.9381 - sparse_categorical_accuracy: 0.2879 - val_loss: 1.8937 - val_sparse_categorical_accuracy: 0.3050
# Epoch 5/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.8671 - sparse_categorical_accuracy: 0.3212 - val_loss: 1.8177 - val_sparse_categorical_accuracy: 0.3490
# Epoch 6/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.7990 - sparse_categorical_accuracy: 0.3505 - val_loss: 1.7656 - val_sparse_categorical_accuracy: 0.3628
# Epoch 7/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.7466 - sparse_categorical_accuracy: 0.3706 - val_loss: 1.7154 - val_sparse_categorical_accuracy: 0.3904
# Epoch 8/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.7097 - sparse_categorical_accuracy: 0.3853 - val_loss: 1.6788 - val_sparse_categorical_accuracy: 0.4004
# Epoch 9/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.6787 - sparse_categorical_accuracy: 0.3958 - val_loss: 1.6492 - val_sparse_categorical_accuracy: 0.4135
# Epoch 10/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.6543 - sparse_categorical_accuracy: 0.4042 - val_loss: 1.6200 - val_sparse_categorical_accuracy: 0.4194
# Epoch 11/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.6253 - sparse_categorical_accuracy: 0.4139 - val_loss: 1.6148 - val_sparse_categorical_accuracy: 0.4201
# Epoch 12/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.6054 - sparse_categorical_accuracy: 0.4217 - val_loss: 1.5821 - val_sparse_categorical_accuracy: 0.4337
# Epoch 13/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.5847 - sparse_categorical_accuracy: 0.4270 - val_loss: 1.5628 - val_sparse_categorical_accuracy: 0.4360
# Epoch 14/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.5668 - sparse_categorical_accuracy: 0.4347 - val_loss: 1.5452 - val_sparse_categorical_accuracy: 0.4430
# Epoch 15/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.5502 - sparse_categorical_accuracy: 0.4405 - val_loss: 1.5254 - val_sparse_categorical_accuracy: 0.4522
# Epoch 16/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.5366 - sparse_categorical_accuracy: 0.4455 - val_loss: 1.5161 - val_sparse_categorical_accuracy: 0.4481
# Epoch 17/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.5216 - sparse_categorical_accuracy: 0.4513 - val_loss: 1.5032 - val_sparse_categorical_accuracy: 0.4553
# Epoch 18/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.5095 - sparse_categorical_accuracy: 0.4541 - val_loss: 1.4945 - val_sparse_categorical_accuracy: 0.4580
# Epoch 19/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.4971 - sparse_categorical_accuracy: 0.4588 - val_loss: 1.4836 - val_sparse_categorical_accuracy: 0.4641
# Epoch 20/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.4836 - sparse_categorical_accuracy: 0.4654 - val_loss: 1.4858 - val_sparse_categorical_accuracy: 0.4667
# Epoch 21/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4758 - sparse_categorical_accuracy: 0.4685 - val_loss: 1.4575 - val_sparse_categorical_accuracy: 0.4749
# Epoch 22/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4634 - sparse_categorical_accuracy: 0.4724 - val_loss: 1.4627 - val_sparse_categorical_accuracy: 0.4715
# Epoch 23/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.4526 - sparse_categorical_accuracy: 0.4780 - val_loss: 1.4458 - val_sparse_categorical_accuracy: 0.4829
# Epoch 24/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.4426 - sparse_categorical_accuracy: 0.4829 - val_loss: 1.4365 - val_sparse_categorical_accuracy: 0.4766
# Epoch 25/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.4276 - sparse_categorical_accuracy: 0.4869 - val_loss: 1.4207 - val_sparse_categorical_accuracy: 0.4871
# Epoch 26/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.4184 - sparse_categorical_accuracy: 0.4902 - val_loss: 1.4505 - val_sparse_categorical_accuracy: 0.4817
# Epoch 27/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.4120 - sparse_categorical_accuracy: 0.4940 - val_loss: 1.4113 - val_sparse_categorical_accuracy: 0.4913
# Epoch 28/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.4006 - sparse_categorical_accuracy: 0.4967 - val_loss: 1.4006 - val_sparse_categorical_accuracy: 0.4971
# Epoch 29/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3896 - sparse_categorical_accuracy: 0.5010 - val_loss: 1.4050 - val_sparse_categorical_accuracy: 0.4895
# Epoch 30/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.3802 - sparse_categorical_accuracy: 0.5054 - val_loss: 1.3900 - val_sparse_categorical_accuracy: 0.4990
# Epoch 31/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3712 - sparse_categorical_accuracy: 0.5086 - val_loss: 1.3880 - val_sparse_categorical_accuracy: 0.4956
# Epoch 32/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3612 - sparse_categorical_accuracy: 0.5118 - val_loss: 1.3687 - val_sparse_categorical_accuracy: 0.5082
# Epoch 33/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3533 - sparse_categorical_accuracy: 0.5159 - val_loss: 1.3616 - val_sparse_categorical_accuracy: 0.5106
# Epoch 34/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.3434 - sparse_categorical_accuracy: 0.5190 - val_loss: 1.3532 - val_sparse_categorical_accuracy: 0.5130
# Epoch 35/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3326 - sparse_categorical_accuracy: 0.5233 - val_loss: 1.3484 - val_sparse_categorical_accuracy: 0.5140
# Epoch 36/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3260 - sparse_categorical_accuracy: 0.5258 - val_loss: 1.3378 - val_sparse_categorical_accuracy: 0.5193
# Epoch 37/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.3161 - sparse_categorical_accuracy: 0.5308 - val_loss: 1.3390 - val_sparse_categorical_accuracy: 0.5168
# Epoch 38/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 1.3117 - sparse_categorical_accuracy: 0.5316 - val_loss: 1.3449 - val_sparse_categorical_accuracy: 0.5209
# Epoch 39/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.3014 - sparse_categorical_accuracy: 0.5357 - val_loss: 1.3231 - val_sparse_categorical_accuracy: 0.5236
# Epoch 40/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2946 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.3183 - val_sparse_categorical_accuracy: 0.5283
# Epoch 41/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2875 - sparse_categorical_accuracy: 0.5396 - val_loss: 1.3160 - val_sparse_categorical_accuracy: 0.5282
# Epoch 42/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2830 - sparse_categorical_accuracy: 0.5415 - val_loss: 1.3154 - val_sparse_categorical_accuracy: 0.5265
# Epoch 43/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2723 - sparse_categorical_accuracy: 0.5463 - val_loss: 1.3256 - val_sparse_categorical_accuracy: 0.5231
# Epoch 44/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2676 - sparse_categorical_accuracy: 0.5483 - val_loss: 1.3058 - val_sparse_categorical_accuracy: 0.5318
# Epoch 45/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2629 - sparse_categorical_accuracy: 0.5508 - val_loss: 1.2977 - val_sparse_categorical_accuracy: 0.5355
# Epoch 46/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2554 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.2913 - val_sparse_categorical_accuracy: 0.5379
# Epoch 47/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2488 - sparse_categorical_accuracy: 0.5567 - val_loss: 1.2969 - val_sparse_categorical_accuracy: 0.5337
# Epoch 48/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2436 - sparse_categorical_accuracy: 0.5576 - val_loss: 1.2934 - val_sparse_categorical_accuracy: 0.5364
# Epoch 49/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.2384 - sparse_categorical_accuracy: 0.5601 - val_loss: 1.2843 - val_sparse_categorical_accuracy: 0.5440
# Epoch 50/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2332 - sparse_categorical_accuracy: 0.5622 - val_loss: 1.2782 - val_sparse_categorical_accuracy: 0.5421
# Epoch 51/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2273 - sparse_categorical_accuracy: 0.5640 - val_loss: 1.2855 - val_sparse_categorical_accuracy: 0.5347
# Epoch 52/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.2251 - sparse_categorical_accuracy: 0.5646 - val_loss: 1.2770 - val_sparse_categorical_accuracy: 0.5394
# Epoch 53/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.2169 - sparse_categorical_accuracy: 0.5664 - val_loss: 1.2818 - val_sparse_categorical_accuracy: 0.5376
# Epoch 54/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2174 - sparse_categorical_accuracy: 0.5663 - val_loss: 1.2776 - val_sparse_categorical_accuracy: 0.5406
# Epoch 55/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2065 - sparse_categorical_accuracy: 0.5710 - val_loss: 1.2728 - val_sparse_categorical_accuracy: 0.5446
# Epoch 56/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.2032 - sparse_categorical_accuracy: 0.5722 - val_loss: 1.2642 - val_sparse_categorical_accuracy: 0.5458
# Epoch 57/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.1960 - sparse_categorical_accuracy: 0.5748 - val_loss: 1.2664 - val_sparse_categorical_accuracy: 0.5465
# Epoch 58/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.1900 - sparse_categorical_accuracy: 0.5781 - val_loss: 1.2567 - val_sparse_categorical_accuracy: 0.5481
# Epoch 59/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.1876 - sparse_categorical_accuracy: 0.5781 - val_loss: 1.2782 - val_sparse_categorical_accuracy: 0.5415
# Epoch 60/60
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 1.1862 - sparse_categorical_accuracy: 0.5793 - val_loss: 1.2596 - val_sparse_categorical_accuracy: 0.5458

# %%
show_training_curves(history)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(1024, activation='leaky_relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)), # Added L2 regularization
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='leaky_relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)), # Added L2 regularization
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),  ## decreased learning rate
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Define EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_sparse_categorical_accuracy',  # Monitor validation accuracy
    mode='max',             # Maximize validation accuracy
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity.
)

history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 4.0848 - sparse_categorical_accuracy: 0.3381 - val_loss: 4.0379 - val_sparse_categorical_accuracy: 0.3916
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 3.7697 - sparse_categorical_accuracy: 0.4158 - val_loss: 3.7571 - val_sparse_categorical_accuracy: 0.4565
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.6004 - sparse_categorical_accuracy: 0.4543 - val_loss: 3.5288 - val_sparse_categorical_accuracy: 0.4846
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.4721 - sparse_categorical_accuracy: 0.4745 - val_loss: 3.3809 - val_sparse_categorical_accuracy: 0.5008
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.3495 - sparse_categorical_accuracy: 0.4873 - val_loss: 3.2753 - val_sparse_categorical_accuracy: 0.5085
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 3.2328 - sparse_categorical_accuracy: 0.5061 - val_loss: 3.1669 - val_sparse_categorical_accuracy: 0.5178
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.1293 - sparse_categorical_accuracy: 0.5157 - val_loss: 3.0795 - val_sparse_categorical_accuracy: 0.5232
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 3.0301 - sparse_categorical_accuracy: 0.5284 - val_loss: 3.0091 - val_sparse_categorical_accuracy: 0.5269
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.9393 - sparse_categorical_accuracy: 0.5399 - val_loss: 2.9314 - val_sparse_categorical_accuracy: 0.5324
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 2.8563 - sparse_categorical_accuracy: 0.5488 - val_loss: 2.8635 - val_sparse_categorical_accuracy: 0.5369
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.7676 - sparse_categorical_accuracy: 0.5587 - val_loss: 2.7890 - val_sparse_categorical_accuracy: 0.5418
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.6902 - sparse_categorical_accuracy: 0.5693 - val_loss: 2.7310 - val_sparse_categorical_accuracy: 0.5387
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.6138 - sparse_categorical_accuracy: 0.5768 - val_loss: 2.6775 - val_sparse_categorical_accuracy: 0.5458
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.5451 - sparse_categorical_accuracy: 0.5827 - val_loss: 2.6277 - val_sparse_categorical_accuracy: 0.5463
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.4741 - sparse_categorical_accuracy: 0.5901 - val_loss: 2.5630 - val_sparse_categorical_accuracy: 0.5534
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 2.4117 - sparse_categorical_accuracy: 0.5987 - val_loss: 2.5084 - val_sparse_categorical_accuracy: 0.5563
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - loss: 2.3517 - sparse_categorical_accuracy: 0.6047 - val_loss: 2.4764 - val_sparse_categorical_accuracy: 0.5498
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 2.2972 - sparse_categorical_accuracy: 0.6097 - val_loss: 2.4287 - val_sparse_categorical_accuracy: 0.5539
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.2415 - sparse_categorical_accuracy: 0.6143 - val_loss: 2.3907 - val_sparse_categorical_accuracy: 0.5532
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.1875 - sparse_categorical_accuracy: 0.6235 - val_loss: 2.3510 - val_sparse_categorical_accuracy: 0.5578
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.1375 - sparse_categorical_accuracy: 0.6271 - val_loss: 2.3152 - val_sparse_categorical_accuracy: 0.5529
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.0844 - sparse_categorical_accuracy: 0.6366 - val_loss: 2.2845 - val_sparse_categorical_accuracy: 0.5606
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 2.0377 - sparse_categorical_accuracy: 0.6417 - val_loss: 2.2627 - val_sparse_categorical_accuracy: 0.5577
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.9980 - sparse_categorical_accuracy: 0.6450 - val_loss: 2.2134 - val_sparse_categorical_accuracy: 0.5615
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.9510 - sparse_categorical_accuracy: 0.6527 - val_loss: 2.1912 - val_sparse_categorical_accuracy: 0.5589
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.9081 - sparse_categorical_accuracy: 0.6594 - val_loss: 2.1691 - val_sparse_categorical_accuracy: 0.5682
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.8737 - sparse_categorical_accuracy: 0.6617 - val_loss: 2.1471 - val_sparse_categorical_accuracy: 0.5606
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.8432 - sparse_categorical_accuracy: 0.6658 - val_loss: 2.1078 - val_sparse_categorical_accuracy: 0.5647
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - loss: 1.8042 - sparse_categorical_accuracy: 0.6712 - val_loss: 2.1171 - val_sparse_categorical_accuracy: 0.5602
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - loss: 1.7617 - sparse_categorical_accuracy: 0.6779 - val_loss: 2.0768 - val_sparse_categorical_accuracy: 0.5654

# %%
show_training_curves(history)

# %%
import tensorflow as tf

def augment_img(image, label):
  # Random horizontal flip
  image = tf.image.random_flip_left_right(image)
  # Random brightness adjustment
  image = tf.image.random_brightness(image, max_delta=0.2)
  # Random contrast adjustment
  image = tf.image.random_contrast(image, lower=0.8, upper=1.2)
  # Random crop by padding and then cropping
  IMG_SIZE = 32
  paddings = tf.constant([[4, 4], [4, 4], [0, 0]]) # Pad by 4 pixels on each side (total 40x40)
  image = tf.pad(image, paddings, "REFLECT") # Use REFLECT padding to avoid black borders
  image = tf.image.random_crop(image, size=[IMG_SIZE, IMG_SIZE, 3])
  return image, label

# Re-build the training pipeline with data augmentation.
# Assumes 'ods_train', 'normalize_img', 'ds_info.splits['train'].num_examples', and 'tf.data.AUTOTUNE' are defined in prior cells.
ds_train = ods_train.map(
    normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
# Apply data augmentation to the training dataset after caching normalized data
ds_train = ds_train.map(
    augment_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(512)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

print("Training dataset pipeline rebuilt with data augmentation.")
print("The new pipeline includes random horizontal flips, brightness, contrast adjustments, and random cropping.")
# Out:
# Training dataset pipeline rebuilt with data augmentation.
# The new pipeline includes random horizontal flips, brightness, contrast adjustments, and random cropping.

# %% [markdown]
# ### Early stopping and learning-rate tuning
# Early stopping halts training when validation accuracy stops improving, which prevents overfitting and saves time. The lower learning rate here ($10^{-4}$) makes updates smaller and can improve stability.

# %% [markdown]
# ### Checkpoints (recommended)
# Use `ModelCheckpoint` to save the best model during training. Add it to the `callbacks` list alongside early stopping.
#
# Example:
# ```python
# checkpoint_cb = tf.keras.callbacks.ModelCheckpoint(
#     filepath='checkpoints/cifar10_ffn.keras',
#     monitor='val_sparse_categorical_accuracy',
#     save_best_only=True,
#     mode='max'
#  )
# history = model.fit(..., callbacks=[early_stopping_callback, checkpoint_cb])
# ```

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.Dense(1024, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(512, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(256, activation='leaky_relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10)
])


model.compile(
    optimizer=tf.keras.optimizers.Adam(0.0001),  ## decreased learning rate
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Define EarlyStopping callback
early_stopping_callback = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',  # Monitor validation accuracy
    mode='max',             # Maximize validation accuracy
    patience=5,          # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True # Restore model weights from the epoch with the best value of the monitored quantity.
)

history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - loss: 2.0413 - sparse_categorical_accuracy: 0.2777 - val_loss: 1.9346 - val_sparse_categorical_accuracy: 0.3943
# Epoch 2/30
# /Users/pewhite/miniconda3/envs/tfmetal-pip/lib/python3.12/site-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_accuracy` which is not available. Available metrics are: loss,sparse_categorical_accuracy,val_loss,val_sparse_categorical_accuracy
#   current = self.get_monitor_value(logs)
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.8538 - sparse_categorical_accuracy: 0.3404 - val_loss: 1.7533 - val_sparse_categorical_accuracy: 0.4360
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7898 - sparse_categorical_accuracy: 0.3615 - val_loss: 1.6311 - val_sparse_categorical_accuracy: 0.4488
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7541 - sparse_categorical_accuracy: 0.3767 - val_loss: 1.5691 - val_sparse_categorical_accuracy: 0.4642
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.7224 - sparse_categorical_accuracy: 0.3870 - val_loss: 1.5274 - val_sparse_categorical_accuracy: 0.4668
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.6952 - sparse_categorical_accuracy: 0.3953 - val_loss: 1.5039 - val_sparse_categorical_accuracy: 0.4788
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.6701 - sparse_categorical_accuracy: 0.4050 - val_loss: 1.4847 - val_sparse_categorical_accuracy: 0.4855
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.6524 - sparse_categorical_accuracy: 0.4119 - val_loss: 1.4769 - val_sparse_categorical_accuracy: 0.4847
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.6425 - sparse_categorical_accuracy: 0.4181 - val_loss: 1.4455 - val_sparse_categorical_accuracy: 0.4989
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.6281 - sparse_categorical_accuracy: 0.4249 - val_loss: 1.4306 - val_sparse_categorical_accuracy: 0.5055
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6105 - sparse_categorical_accuracy: 0.4280 - val_loss: 1.4204 - val_sparse_categorical_accuracy: 0.5072
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.6048 - sparse_categorical_accuracy: 0.4315 - val_loss: 1.4174 - val_sparse_categorical_accuracy: 0.5044
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5874 - sparse_categorical_accuracy: 0.4355 - val_loss: 1.4011 - val_sparse_categorical_accuracy: 0.5148
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.5801 - sparse_categorical_accuracy: 0.4390 - val_loss: 1.3920 - val_sparse_categorical_accuracy: 0.5185
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.5687 - sparse_categorical_accuracy: 0.4454 - val_loss: 1.3855 - val_sparse_categorical_accuracy: 0.5157
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.5606 - sparse_categorical_accuracy: 0.4444 - val_loss: 1.3687 - val_sparse_categorical_accuracy: 0.5243
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5459 - sparse_categorical_accuracy: 0.4484 - val_loss: 1.3586 - val_sparse_categorical_accuracy: 0.5300
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5484 - sparse_categorical_accuracy: 0.4500 - val_loss: 1.3568 - val_sparse_categorical_accuracy: 0.5283
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5341 - sparse_categorical_accuracy: 0.4563 - val_loss: 1.3501 - val_sparse_categorical_accuracy: 0.5350
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.5256 - sparse_categorical_accuracy: 0.4578 - val_loss: 1.3427 - val_sparse_categorical_accuracy: 0.5274
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5206 - sparse_categorical_accuracy: 0.4625 - val_loss: 1.3354 - val_sparse_categorical_accuracy: 0.5334
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5159 - sparse_categorical_accuracy: 0.4603 - val_loss: 1.3244 - val_sparse_categorical_accuracy: 0.5369
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.5052 - sparse_categorical_accuracy: 0.4669 - val_loss: 1.3164 - val_sparse_categorical_accuracy: 0.5383
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4956 - sparse_categorical_accuracy: 0.4658 - val_loss: 1.3282 - val_sparse_categorical_accuracy: 0.5442
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 1.4907 - sparse_categorical_accuracy: 0.4723 - val_loss: 1.3103 - val_sparse_categorical_accuracy: 0.5407
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4887 - sparse_categorical_accuracy: 0.4710 - val_loss: 1.3002 - val_sparse_categorical_accuracy: 0.5404
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4774 - sparse_categorical_accuracy: 0.4749 - val_loss: 1.2915 - val_sparse_categorical_accuracy: 0.5501
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4687 - sparse_categorical_accuracy: 0.4785 - val_loss: 1.2932 - val_sparse_categorical_accuracy: 0.5487
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4655 - sparse_categorical_accuracy: 0.4786 - val_loss: 1.2893 - val_sparse_categorical_accuracy: 0.5474
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.4651 - sparse_categorical_accuracy: 0.4786 - val_loss: 1.2818 - val_sparse_categorical_accuracy: 0.5524

# %%
show_training_curves(history)

# %% [markdown]
# ### Data augmentation
# Augmentation makes the model more robust by creating varied training examples. We apply flips, brightness/contrast changes, and random crops **after** caching normalized images.

# %% [markdown]
# After rebuilding the pipeline, recompile and retrain the model so it learns from the augmented data. Compare the new learning curves to the earlier baseline.

# %%
more_history = model.fit(
    ds_train,
    epochs=30,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4510 - sparse_categorical_accuracy: 0.4847 - val_loss: 1.2735 - val_sparse_categorical_accuracy: 0.5549
# Epoch 2/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4550 - sparse_categorical_accuracy: 0.4809 - val_loss: 1.2747 - val_sparse_categorical_accuracy: 0.5552
# Epoch 3/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4505 - sparse_categorical_accuracy: 0.4821 - val_loss: 1.2623 - val_sparse_categorical_accuracy: 0.5568
# Epoch 4/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4475 - sparse_categorical_accuracy: 0.4834 - val_loss: 1.2624 - val_sparse_categorical_accuracy: 0.5553
# Epoch 5/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4399 - sparse_categorical_accuracy: 0.4895 - val_loss: 1.2589 - val_sparse_categorical_accuracy: 0.5536
# Epoch 6/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4386 - sparse_categorical_accuracy: 0.4865 - val_loss: 1.2503 - val_sparse_categorical_accuracy: 0.5612
# Epoch 7/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4319 - sparse_categorical_accuracy: 0.4891 - val_loss: 1.2540 - val_sparse_categorical_accuracy: 0.5582
# Epoch 8/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4239 - sparse_categorical_accuracy: 0.4926 - val_loss: 1.2529 - val_sparse_categorical_accuracy: 0.5670
# Epoch 9/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4220 - sparse_categorical_accuracy: 0.4925 - val_loss: 1.2435 - val_sparse_categorical_accuracy: 0.5610
# Epoch 10/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4182 - sparse_categorical_accuracy: 0.4927 - val_loss: 1.2333 - val_sparse_categorical_accuracy: 0.5702
# Epoch 11/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4136 - sparse_categorical_accuracy: 0.4956 - val_loss: 1.2351 - val_sparse_categorical_accuracy: 0.5691
# Epoch 12/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.4126 - sparse_categorical_accuracy: 0.4962 - val_loss: 1.2340 - val_sparse_categorical_accuracy: 0.5683
# Epoch 13/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4078 - sparse_categorical_accuracy: 0.4980 - val_loss: 1.2301 - val_sparse_categorical_accuracy: 0.5662
# Epoch 14/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.4008 - sparse_categorical_accuracy: 0.5003 - val_loss: 1.2245 - val_sparse_categorical_accuracy: 0.5708
# Epoch 15/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3984 - sparse_categorical_accuracy: 0.5016 - val_loss: 1.2264 - val_sparse_categorical_accuracy: 0.5682
# Epoch 16/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3961 - sparse_categorical_accuracy: 0.5015 - val_loss: 1.2246 - val_sparse_categorical_accuracy: 0.5687
# Epoch 17/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3927 - sparse_categorical_accuracy: 0.5001 - val_loss: 1.2181 - val_sparse_categorical_accuracy: 0.5704
# Epoch 18/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3897 - sparse_categorical_accuracy: 0.5013 - val_loss: 1.2131 - val_sparse_categorical_accuracy: 0.5754
# Epoch 19/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3858 - sparse_categorical_accuracy: 0.5038 - val_loss: 1.2173 - val_sparse_categorical_accuracy: 0.5669
# Epoch 20/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3857 - sparse_categorical_accuracy: 0.5035 - val_loss: 1.2104 - val_sparse_categorical_accuracy: 0.5765
# Epoch 21/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3846 - sparse_categorical_accuracy: 0.5073 - val_loss: 1.2046 - val_sparse_categorical_accuracy: 0.5756
# Epoch 22/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3806 - sparse_categorical_accuracy: 0.5092 - val_loss: 1.2094 - val_sparse_categorical_accuracy: 0.5722
# Epoch 23/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3786 - sparse_categorical_accuracy: 0.5050 - val_loss: 1.2042 - val_sparse_categorical_accuracy: 0.5755
# Epoch 24/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3774 - sparse_categorical_accuracy: 0.5063 - val_loss: 1.2053 - val_sparse_categorical_accuracy: 0.5754
# Epoch 25/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3675 - sparse_categorical_accuracy: 0.5103 - val_loss: 1.2001 - val_sparse_categorical_accuracy: 0.5800
# Epoch 26/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3701 - sparse_categorical_accuracy: 0.5137 - val_loss: 1.2110 - val_sparse_categorical_accuracy: 0.5713
# Epoch 27/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3726 - sparse_categorical_accuracy: 0.5100 - val_loss: 1.1942 - val_sparse_categorical_accuracy: 0.5785
# Epoch 28/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3572 - sparse_categorical_accuracy: 0.5129 - val_loss: 1.1866 - val_sparse_categorical_accuracy: 0.5824
# Epoch 29/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3595 - sparse_categorical_accuracy: 0.5137 - val_loss: 1.1940 - val_sparse_categorical_accuracy: 0.5798
# Epoch 30/30
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.3566 - sparse_categorical_accuracy: 0.5179 - val_loss: 1.1919 - val_sparse_categorical_accuracy: 0.5822

# %%
for key in more_history.history:
    history.history[key].extend(more_history.history[key])

# %%
show_training_curves(history)

# %%
more_history = model.fit(
    ds_train,
    epochs=100,
    validation_data=ds_test,
    callbacks=[early_stopping_callback] # Add early stopping callback
)
# Out:
# Epoch 1/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3538 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.1917 - val_sparse_categorical_accuracy: 0.5815
# Epoch 2/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3493 - sparse_categorical_accuracy: 0.5191 - val_loss: 1.1861 - val_sparse_categorical_accuracy: 0.5770
# Epoch 3/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3509 - sparse_categorical_accuracy: 0.5161 - val_loss: 1.1770 - val_sparse_categorical_accuracy: 0.5839
# Epoch 4/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3486 - sparse_categorical_accuracy: 0.5155 - val_loss: 1.1826 - val_sparse_categorical_accuracy: 0.5872
# Epoch 5/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3482 - sparse_categorical_accuracy: 0.5178 - val_loss: 1.1795 - val_sparse_categorical_accuracy: 0.5823
# Epoch 6/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3439 - sparse_categorical_accuracy: 0.5205 - val_loss: 1.1790 - val_sparse_categorical_accuracy: 0.5860
# Epoch 7/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3381 - sparse_categorical_accuracy: 0.5236 - val_loss: 1.1792 - val_sparse_categorical_accuracy: 0.5830
# Epoch 8/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3384 - sparse_categorical_accuracy: 0.5227 - val_loss: 1.1769 - val_sparse_categorical_accuracy: 0.5815
# Epoch 9/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3322 - sparse_categorical_accuracy: 0.5239 - val_loss: 1.1708 - val_sparse_categorical_accuracy: 0.5836
# Epoch 10/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3333 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.1679 - val_sparse_categorical_accuracy: 0.5859
# Epoch 11/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3321 - sparse_categorical_accuracy: 0.5225 - val_loss: 1.1611 - val_sparse_categorical_accuracy: 0.5907
# Epoch 12/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3277 - sparse_categorical_accuracy: 0.5273 - val_loss: 1.1629 - val_sparse_categorical_accuracy: 0.5895
# Epoch 13/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3282 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.1670 - val_sparse_categorical_accuracy: 0.5854
# Epoch 14/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3234 - sparse_categorical_accuracy: 0.5289 - val_loss: 1.1635 - val_sparse_categorical_accuracy: 0.5915
# Epoch 15/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3286 - sparse_categorical_accuracy: 0.5248 - val_loss: 1.1611 - val_sparse_categorical_accuracy: 0.5901
# Epoch 16/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3272 - sparse_categorical_accuracy: 0.5297 - val_loss: 1.1550 - val_sparse_categorical_accuracy: 0.5914
# Epoch 17/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3135 - sparse_categorical_accuracy: 0.5310 - val_loss: 1.1606 - val_sparse_categorical_accuracy: 0.5868
# Epoch 18/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3164 - sparse_categorical_accuracy: 0.5312 - val_loss: 1.1515 - val_sparse_categorical_accuracy: 0.5948
# Epoch 19/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3143 - sparse_categorical_accuracy: 0.5311 - val_loss: 1.1539 - val_sparse_categorical_accuracy: 0.5909
# Epoch 20/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3138 - sparse_categorical_accuracy: 0.5329 - val_loss: 1.1469 - val_sparse_categorical_accuracy: 0.5964
# Epoch 21/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3064 - sparse_categorical_accuracy: 0.5338 - val_loss: 1.1467 - val_sparse_categorical_accuracy: 0.5944
# Epoch 22/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3087 - sparse_categorical_accuracy: 0.5344 - val_loss: 1.1494 - val_sparse_categorical_accuracy: 0.5943
# Epoch 23/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3089 - sparse_categorical_accuracy: 0.5322 - val_loss: 1.1471 - val_sparse_categorical_accuracy: 0.5960
# Epoch 24/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3091 - sparse_categorical_accuracy: 0.5320 - val_loss: 1.1406 - val_sparse_categorical_accuracy: 0.6001
# Epoch 25/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3038 - sparse_categorical_accuracy: 0.5338 - val_loss: 1.1458 - val_sparse_categorical_accuracy: 0.5974
# Epoch 26/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3020 - sparse_categorical_accuracy: 0.5349 - val_loss: 1.1415 - val_sparse_categorical_accuracy: 0.5972
# Epoch 27/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.3019 - sparse_categorical_accuracy: 0.5339 - val_loss: 1.1393 - val_sparse_categorical_accuracy: 0.5976
# Epoch 28/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3010 - sparse_categorical_accuracy: 0.5358 - val_loss: 1.1370 - val_sparse_categorical_accuracy: 0.5952
# Epoch 29/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2978 - sparse_categorical_accuracy: 0.5367 - val_loss: 1.1341 - val_sparse_categorical_accuracy: 0.5985
# Epoch 30/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.3021 - sparse_categorical_accuracy: 0.5338 - val_loss: 1.1294 - val_sparse_categorical_accuracy: 0.6022
# Epoch 31/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2962 - sparse_categorical_accuracy: 0.5375 - val_loss: 1.1326 - val_sparse_categorical_accuracy: 0.5966
# Epoch 32/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2945 - sparse_categorical_accuracy: 0.5393 - val_loss: 1.1353 - val_sparse_categorical_accuracy: 0.5982
# Epoch 33/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2946 - sparse_categorical_accuracy: 0.5367 - val_loss: 1.1249 - val_sparse_categorical_accuracy: 0.6037
# Epoch 34/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2880 - sparse_categorical_accuracy: 0.5389 - val_loss: 1.1206 - val_sparse_categorical_accuracy: 0.6045
# Epoch 35/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2877 - sparse_categorical_accuracy: 0.5419 - val_loss: 1.1248 - val_sparse_categorical_accuracy: 0.6003
# Epoch 36/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2866 - sparse_categorical_accuracy: 0.5438 - val_loss: 1.1289 - val_sparse_categorical_accuracy: 0.5991
# Epoch 37/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2841 - sparse_categorical_accuracy: 0.5426 - val_loss: 1.1290 - val_sparse_categorical_accuracy: 0.5976
# Epoch 38/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2845 - sparse_categorical_accuracy: 0.5427 - val_loss: 1.1237 - val_sparse_categorical_accuracy: 0.6040
# Epoch 39/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2788 - sparse_categorical_accuracy: 0.5449 - val_loss: 1.1161 - val_sparse_categorical_accuracy: 0.6004
# Epoch 40/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2785 - sparse_categorical_accuracy: 0.5449 - val_loss: 1.1161 - val_sparse_categorical_accuracy: 0.6057
# Epoch 41/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2786 - sparse_categorical_accuracy: 0.5427 - val_loss: 1.1142 - val_sparse_categorical_accuracy: 0.6047
# Epoch 42/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2767 - sparse_categorical_accuracy: 0.5447 - val_loss: 1.1136 - val_sparse_categorical_accuracy: 0.6033
# Epoch 43/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2708 - sparse_categorical_accuracy: 0.5456 - val_loss: 1.1120 - val_sparse_categorical_accuracy: 0.6016
# Epoch 44/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2800 - sparse_categorical_accuracy: 0.5444 - val_loss: 1.1132 - val_sparse_categorical_accuracy: 0.6058
# Epoch 45/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2753 - sparse_categorical_accuracy: 0.5440 - val_loss: 1.1108 - val_sparse_categorical_accuracy: 0.6066
# Epoch 46/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2677 - sparse_categorical_accuracy: 0.5508 - val_loss: 1.1150 - val_sparse_categorical_accuracy: 0.6055
# Epoch 47/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2740 - sparse_categorical_accuracy: 0.5461 - val_loss: 1.1124 - val_sparse_categorical_accuracy: 0.6058
# Epoch 48/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2674 - sparse_categorical_accuracy: 0.5466 - val_loss: 1.1123 - val_sparse_categorical_accuracy: 0.6085
# Epoch 49/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2627 - sparse_categorical_accuracy: 0.5507 - val_loss: 1.1052 - val_sparse_categorical_accuracy: 0.6095
# Epoch 50/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2655 - sparse_categorical_accuracy: 0.5471 - val_loss: 1.1128 - val_sparse_categorical_accuracy: 0.6046
# Epoch 51/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - loss: 1.2651 - sparse_categorical_accuracy: 0.5486 - val_loss: 1.1122 - val_sparse_categorical_accuracy: 0.6052
# Epoch 52/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2628 - sparse_categorical_accuracy: 0.5464 - val_loss: 1.1055 - val_sparse_categorical_accuracy: 0.6052
# Epoch 53/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2614 - sparse_categorical_accuracy: 0.5507 - val_loss: 1.1057 - val_sparse_categorical_accuracy: 0.6049
# Epoch 54/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2659 - sparse_categorical_accuracy: 0.5496 - val_loss: 1.1046 - val_sparse_categorical_accuracy: 0.6024
# Epoch 55/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2552 - sparse_categorical_accuracy: 0.5505 - val_loss: 1.0994 - val_sparse_categorical_accuracy: 0.6095
# Epoch 56/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2565 - sparse_categorical_accuracy: 0.5515 - val_loss: 1.1037 - val_sparse_categorical_accuracy: 0.6055
# Epoch 57/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2491 - sparse_categorical_accuracy: 0.5529 - val_loss: 1.1009 - val_sparse_categorical_accuracy: 0.6103
# Epoch 58/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2581 - sparse_categorical_accuracy: 0.5542 - val_loss: 1.0958 - val_sparse_categorical_accuracy: 0.6100
# Epoch 59/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2586 - sparse_categorical_accuracy: 0.5510 - val_loss: 1.0988 - val_sparse_categorical_accuracy: 0.6115
# Epoch 60/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2544 - sparse_categorical_accuracy: 0.5505 - val_loss: 1.0977 - val_sparse_categorical_accuracy: 0.6080
# Epoch 61/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2540 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.0989 - val_sparse_categorical_accuracy: 0.6067
# Epoch 62/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2530 - sparse_categorical_accuracy: 0.5538 - val_loss: 1.1028 - val_sparse_categorical_accuracy: 0.6081
# Epoch 63/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2502 - sparse_categorical_accuracy: 0.5563 - val_loss: 1.0901 - val_sparse_categorical_accuracy: 0.6124
# Epoch 64/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2437 - sparse_categorical_accuracy: 0.5567 - val_loss: 1.0928 - val_sparse_categorical_accuracy: 0.6113
# Epoch 65/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2483 - sparse_categorical_accuracy: 0.5549 - val_loss: 1.0900 - val_sparse_categorical_accuracy: 0.6099
# Epoch 66/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2402 - sparse_categorical_accuracy: 0.5612 - val_loss: 1.0890 - val_sparse_categorical_accuracy: 0.6122
# Epoch 67/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2430 - sparse_categorical_accuracy: 0.5545 - val_loss: 1.0918 - val_sparse_categorical_accuracy: 0.6100
# Epoch 68/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2401 - sparse_categorical_accuracy: 0.5556 - val_loss: 1.0865 - val_sparse_categorical_accuracy: 0.6150
# Epoch 69/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2374 - sparse_categorical_accuracy: 0.5596 - val_loss: 1.0824 - val_sparse_categorical_accuracy: 0.6143
# Epoch 70/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2410 - sparse_categorical_accuracy: 0.5565 - val_loss: 1.0889 - val_sparse_categorical_accuracy: 0.6159
# Epoch 71/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2385 - sparse_categorical_accuracy: 0.5599 - val_loss: 1.0791 - val_sparse_categorical_accuracy: 0.6155
# Epoch 72/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2405 - sparse_categorical_accuracy: 0.5582 - val_loss: 1.0859 - val_sparse_categorical_accuracy: 0.6142
# Epoch 73/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2297 - sparse_categorical_accuracy: 0.5614 - val_loss: 1.0755 - val_sparse_categorical_accuracy: 0.6155
# Epoch 74/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2323 - sparse_categorical_accuracy: 0.5610 - val_loss: 1.0771 - val_sparse_categorical_accuracy: 0.6153
# Epoch 75/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2346 - sparse_categorical_accuracy: 0.5602 - val_loss: 1.0803 - val_sparse_categorical_accuracy: 0.6158
# Epoch 76/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2363 - sparse_categorical_accuracy: 0.5572 - val_loss: 1.0807 - val_sparse_categorical_accuracy: 0.6120
# Epoch 77/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2303 - sparse_categorical_accuracy: 0.5622 - val_loss: 1.0760 - val_sparse_categorical_accuracy: 0.6170
# Epoch 78/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2328 - sparse_categorical_accuracy: 0.5623 - val_loss: 1.0839 - val_sparse_categorical_accuracy: 0.6152
# Epoch 79/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2267 - sparse_categorical_accuracy: 0.5605 - val_loss: 1.0752 - val_sparse_categorical_accuracy: 0.6161
# Epoch 80/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2299 - sparse_categorical_accuracy: 0.5606 - val_loss: 1.0805 - val_sparse_categorical_accuracy: 0.6166
# Epoch 81/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2293 - sparse_categorical_accuracy: 0.5602 - val_loss: 1.0767 - val_sparse_categorical_accuracy: 0.6161
# Epoch 82/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2241 - sparse_categorical_accuracy: 0.5618 - val_loss: 1.0758 - val_sparse_categorical_accuracy: 0.6194
# Epoch 83/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2289 - sparse_categorical_accuracy: 0.5614 - val_loss: 1.0695 - val_sparse_categorical_accuracy: 0.6178
# Epoch 84/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2227 - sparse_categorical_accuracy: 0.5650 - val_loss: 1.0749 - val_sparse_categorical_accuracy: 0.6156
# Epoch 85/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2215 - sparse_categorical_accuracy: 0.5635 - val_loss: 1.0766 - val_sparse_categorical_accuracy: 0.6193
# Epoch 86/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2189 - sparse_categorical_accuracy: 0.5648 - val_loss: 1.0715 - val_sparse_categorical_accuracy: 0.6164
# Epoch 87/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2187 - sparse_categorical_accuracy: 0.5638 - val_loss: 1.0722 - val_sparse_categorical_accuracy: 0.6151
# Epoch 88/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2207 - sparse_categorical_accuracy: 0.5640 - val_loss: 1.0711 - val_sparse_categorical_accuracy: 0.6180
# Epoch 89/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 1.2206 - sparse_categorical_accuracy: 0.5666 - val_loss: 1.0665 - val_sparse_categorical_accuracy: 0.6200
# Epoch 90/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2159 - sparse_categorical_accuracy: 0.5660 - val_loss: 1.0654 - val_sparse_categorical_accuracy: 0.6193
# Epoch 91/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2140 - sparse_categorical_accuracy: 0.5640 - val_loss: 1.0699 - val_sparse_categorical_accuracy: 0.6158
# Epoch 92/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2155 - sparse_categorical_accuracy: 0.5669 - val_loss: 1.0653 - val_sparse_categorical_accuracy: 0.6215
# Epoch 93/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2166 - sparse_categorical_accuracy: 0.5627 - val_loss: 1.0611 - val_sparse_categorical_accuracy: 0.6226
# Epoch 94/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2170 - sparse_categorical_accuracy: 0.5636 - val_loss: 1.0617 - val_sparse_categorical_accuracy: 0.6194
# Epoch 95/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2136 - sparse_categorical_accuracy: 0.5683 - val_loss: 1.0635 - val_sparse_categorical_accuracy: 0.6200
# Epoch 96/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 1.2081 - sparse_categorical_accuracy: 0.5703 - val_loss: 1.0638 - val_sparse_categorical_accuracy: 0.6241
# Epoch 97/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2066 - sparse_categorical_accuracy: 0.5713 - val_loss: 1.0660 - val_sparse_categorical_accuracy: 0.6159
# Epoch 98/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2064 - sparse_categorical_accuracy: 0.5722 - val_loss: 1.0570 - val_sparse_categorical_accuracy: 0.6252
# Epoch 99/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2118 - sparse_categorical_accuracy: 0.5688 - val_loss: 1.0567 - val_sparse_categorical_accuracy: 0.6230
# Epoch 100/100
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 1.2068 - sparse_categorical_accuracy: 0.5688 - val_loss: 1.0541 - val_sparse_categorical_accuracy: 0.6220

# %%
for key in more_history.history:
    history.history[key].extend(more_history.history[key])

# %%
show_training_curves(history)
