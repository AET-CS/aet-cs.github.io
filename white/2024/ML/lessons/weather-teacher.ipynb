# %%
import pandas as pd
import pytz

# %%
# Read the data file
weather_data_path = '../data/weather-daylight.csv'
weather_data = pd.read_csv(weather_data_path)

# %%
# Calculate total precipitation (p01i) for each day of the week
total_p01i_per_day_et = weather_data.groupby('Day Of Week ET')['p01i'].sum()

# Calculate percentage of OVC and CLR days
percentage_ovc_days_et = (weather_data[weather_data['skyc1'] == 'OVC'].groupby('Day Of Week ET').size() / weather_data.groupby('Day Of Week ET').size()) * 100
percentage_clr_days_et = (weather_data[weather_data['skyc1'] == 'CLR'].groupby('Day Of Week ET').size() / weather_data.groupby('Day Of Week ET').size()) * 100

# Calculate total number of rows (observations) for each day of the week
total_rows_per_day_et = weather_data.groupby('Day Of Week ET').size()

# Combine all the data into one DataFrame
combined_et_df = pd.DataFrame({
    'Day Of Week ET': total_rows_per_day_et.index,
    'Total Number of Rows ET': total_rows_per_day_et.values,
    'Total p01i ET': total_p01i_per_day_et.values,
    'Percentage of OVC Days ET': percentage_ovc_days_et.values,
    'Percentage of CLR Days ET': percentage_clr_days_et.values
})

# Print the final table
print(combined_et_df)
# Out:
#    Day Of Week ET  Total Number of Rows ET  Total p01i ET  \
# 0               0                      852           0.30
# 1               1                      848           5.15
# 2               2                      850           0.67
# 3               3                      841           0.41
# 4               4                      883           0.58
# 5               5                      886           7.28
# 6               6                      857           0.16
#
#    Percentage of OVC Days ET  Percentage of CLR Days ET
# 0                  20.539906                  45.187793
# 1                  28.655660                  42.688679
# 2                  28.235294                  50.705882
# 3                  14.863258                  61.355529
# 4                  15.175538                  55.379388
# 5                  26.523702                  38.487585
# 6                  25.437573                  38.389732

# %%
weather_data.groupby('Day Of Week ET')['p01i'].sum()
# Out:
# Day Of Week ET
# 0    0.30
# 1    5.15
# 2    0.67
# 3    0.41
# 4    0.58
# 5    7.28
# 6    0.16
# Name: p01i, dtype: float64

# %%
# !pip install astral
# Out:
# Collecting astral
#   Downloading astral-3.2-py3-none-any.whl.metadata (1.7 kB)
# Downloading astral-3.2-py3-none-any.whl (38 kB)
# Installing collected packages: astral
# Successfully installed astral-3.2
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from astral.sun import sun
from astral import LocationInfo
from datetime import date

# Specify the location (Washington, DC in this example)
city = LocationInfo("Washington", "USA", "US/Eastern", 38.9072, -77.0369)

# Choose a date
s = sun(city.observer, date=date(2023, 9, 1))

# %%
s

# %%
t=weather_data['valid'][1000]

# %%
# Define a function to calculate sunrise for a single row
def calculate_sunrise(row):
    # Extract the date from the 'valid' column (assuming it's already in datetime format)
    valid_date = row['valid'].date()
    # Calculate sunrise using the astral library
    s = sun(city.observer, date=valid_date)
    return s['sunrise']

def calculate_sunset(row):
    # Extract the date from the 'valid' column (assuming it's already in datetime format)
    valid_date = row['valid'].date()
    # Calculate sunrise using the astral library
    s = sun(city.observer, date=valid_date)
    return s['sunset']

def calculate_daylight(row):
    valid_date = row['valid'].date()
    s = sun(city.observer, date = valid_date)
    return s['sunset']>row['valid']>s['sunrise']

# Apply the function to each row of the DataFrame
# Note: If 'valid' is not in the datetime format, you'll need to convert it first
weather_data['sunrise'] = weather_data.apply(calculate_sunrise, axis=1)
weather_data['sunset'] = weather_data.apply(calculate_sunset, axis=1)
weather_data['daylight'] = weather_data.apply(calculate_daylight, axis=1)

# %%
weather_data['daylight']

# %%
new_data = weather_data[weather_data['daylight']]

# %%
new_data

# %%
new_data.to_csv('weather-daylight.csv')

# %%
# Recalculate the necessary components based on the 'Day Of Week ET' column from the new dataset with daylight information

# Total precipitation (p01i) for each day of the week
total_p01i_per_day_et_new = new_data.groupby('Day Of Week ET')['p01i'].sum()

# Percentage of OVC and CLR days
percentage_ovc_days_et_new = (new_data[(new_data['skyc1'] == 'OVC') | (new_data['skyc2'] == 'OVC') | (new_data['skyc3'] == 'OVC')].groupby('Day Of Week ET').size() / new_data.groupby('Day Of Week ET').size()) * 100
percentage_clr_days_et_new = (new_data[new_data['skyc1'] == 'CLR'].groupby('Day Of Week ET').size() / new_data.groupby('Day Of Week ET').size()) * 100

# Total number of rows (observations) for each day of the week
total_rows_per_day_et_new = new_data.groupby('Day Of Week ET').size()

# Combine all the data into one DataFrame
combined_et_df_new = pd.DataFrame({
    'Day Of Week ET': total_rows_per_day_et_new.index,
    'Total Number of Rows ET': total_rows_per_day_et_new.values,
    'Total p01i ET': total_p01i_per_day_et_new.values,
    'Percentage of OVC Days ET': percentage_ovc_days_et_new.values,
    'Percentage of CLR Days ET': percentage_clr_days_et_new.values
})

combined_et_df_new

# %% [markdown]
# # Cloudy Days in Leesburg

# %% [markdown]
# Analyze Weather data

# %%
df = pd.read_csv('../data/weather-daylight.csv')

# %%
df
# Out:
#        id1    id2 station                      valid  tmpf  dwpf    relh  \
# 0        0     32     JYO  2023-09-01 10:55:00+00:00  59.0  50.0   72.01
# 1        1     33     JYO  2023-09-01 11:15:00+00:00  59.0  50.0   72.01
# 2        2     34     JYO  2023-09-01 11:35:00+00:00  59.0  50.0   72.01
# 3        3     35     JYO  2023-09-01 11:55:00+00:00  60.8  51.8   72.20
# 4        4     36     JYO  2023-09-01 12:15:00+00:00  62.6  51.8   67.75
# ...    ...    ...     ...                        ...   ...   ...     ...
# 6012  6012  13576     JYO  2024-03-09 21:35:00+00:00  44.6  44.6  100.00
# 6013  6013  13577     JYO  2024-03-09 21:55:00+00:00  44.6  44.6  100.00
# 6014  6014  13578     JYO  2024-03-09 22:15:00+00:00  44.6  44.6  100.00
# 6015  6015  13579     JYO  2024-03-09 22:35:00+00:00  44.6  44.6  100.00
# 6016  6016  13580     JYO  2024-03-09 22:55:00+00:00  44.6  44.6  100.00
#
#        drct  sknt  p01i  ...  peak_wind_drct  peak_wind_time   feel  \
# 0      20.0   5.0  0.00  ...             NaN             NaN  59.00
# 1      20.0   6.0  0.00  ...             NaN             NaN  59.00
# 2      20.0   6.0  0.00  ...             NaN             NaN  59.00
# 3      30.0   7.0  0.00  ...             NaN             NaN  60.80
# 4      30.0   8.0  0.00  ...             NaN             NaN  62.60
# ...     ...   ...   ...  ...             ...             ...    ...
# 6012  350.0   9.0  0.03  ...             NaN             NaN  39.18
# 6013   10.0   7.0  0.05  ...             NaN             NaN  40.14
# 6014  360.0   8.0  0.02  ...             NaN             NaN  39.63
# 6015  340.0  11.0  0.13  ...             NaN             NaN  38.39
# 6016  320.0  12.0  0.20  ...             NaN             NaN  38.04
#
#                                                   metar snowdepth  \
# 0     KJYO 011055Z AUTO 02005KT 10SM CLR 15/10 A3026...       NaN
# 1     KJYO 011115Z AUTO 02006KT 10SM CLR 15/10 A3027...       NaN
# 2     KJYO 011135Z AUTO 02006KT 10SM CLR 15/10 A3028...       NaN
# 3     KJYO 011155Z AUTO 03007KT 10SM CLR 16/11 A3029...       NaN
# 4     KJYO 011215Z AUTO 03008KT 10SM CLR 17/11 A3029...       NaN
# ...                                                 ...       ...
# 6012  KJYO 092135Z AUTO 35009KT 1 3/4SM -RA BKN004 O...       NaN
# 6013  KJYO 092155Z AUTO 01007KT 1 3/4SM -RA OVC004 0...       NaN
# 6014  KJYO 092215Z AUTO 36008KT 1 1/2SM -VCTSRA OVC0...       NaN
# 6015  KJYO 092235Z AUTO 34011KT 2 1/2SM +TSRA BKN004...       NaN
# 6016  KJYO 092255Z AUTO 32012G17KT 5SM TSRA BKN006 O...       NaN
#
#                        valid_ET Day Of Week ET  \
# 0     2023-09-01 06:55:00-04:00              4
# 1     2023-09-01 07:15:00-04:00              4
# 2     2023-09-01 07:35:00-04:00              4
# 3     2023-09-01 07:55:00-04:00              4
# 4     2023-09-01 08:15:00-04:00              4
# ...                         ...            ...
# 6012  2024-03-09 16:35:00-05:00              5
# 6013  2024-03-09 16:55:00-05:00              5
# 6014  2024-03-09 17:15:00-05:00              5
# 6015  2024-03-09 17:35:00-05:00              5
# 6016  2024-03-09 17:55:00-05:00              5
#
#                                sunrise                            sunset  \
# 0     2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 1     2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 2     2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 3     2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 4     2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# ...                                ...                               ...
# 6012  2024-03-09 11:28:03.012997+00:00  2024-03-09 23:09:29.702861+00:00
# 6013  2024-03-09 11:28:03.012997+00:00  2024-03-09 23:09:29.702861+00:00
# 6014  2024-03-09 11:28:03.012997+00:00  2024-03-09 23:09:29.702861+00:00
# 6015  2024-03-09 11:28:03.012997+00:00  2024-03-09 23:09:29.702861+00:00
# 6016  2024-03-09 11:28:03.012997+00:00  2024-03-09 23:09:29.702861+00:00
#
#       daylight
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# ...        ...
# 6012      True
# 6013      True
# 6014      True
# 6015      True
# 6016      True
#
# [6017 rows x 37 columns]

# %%
df.describe()
# Out:
#                id1           id2         tmpf         dwpf         relh  \
# count  6017.000000   6017.000000  5705.000000  5705.000000  5705.000000
# mean   3008.000000   6612.157554    53.963786    42.250692    67.665832
# std    1737.102616   4065.241617    15.380499    14.652600    20.595358
# min       0.000000     32.000000    12.200000     5.000000    22.810000
# 25%    1504.000000   2943.000000    42.800000    32.000000    51.610000
# 50%    3008.000000   6432.000000    51.800000    41.000000    64.230000
# 75%    4512.000000  10234.000000    64.400000    53.600000    86.490000
# max    6016.000000  13580.000000    96.800000    73.400000   100.000000
#
#               drct         sknt         p01i         alti  mslp  ...  skyl4  \
# count  6008.000000  6008.000000  6017.000000  6011.000000   0.0  ...    0.0
# mean    165.269640     5.953395     0.002418    30.082078   NaN  ...    NaN
# std     137.476461     4.963944     0.024501     0.235834   NaN  ...    NaN
# min       0.000000     0.000000     0.000000    29.320000   NaN  ...    NaN
# 25%      10.000000     3.000000     0.000000    29.920000   NaN  ...    NaN
# 50%     180.000000     5.000000     0.000000    30.080000   NaN  ...    NaN
# 75%     310.000000     9.000000     0.000000    30.230000   NaN  ...    NaN
# max     360.000000    28.000000     0.950000    30.760000   NaN  ...    NaN
#
#        ice_accretion_1hr  ice_accretion_3hr  ice_accretion_6hr  \
# count                0.0                0.0                0.0
# mean                 NaN                NaN                NaN
# std                  NaN                NaN                NaN
# min                  NaN                NaN                NaN
# 25%                  NaN                NaN                NaN
# 50%                  NaN                NaN                NaN
# 75%                  NaN                NaN                NaN
# max                  NaN                NaN                NaN
#
#        peak_wind_gust  peak_wind_drct  peak_wind_time         feel  snowdepth  \
# count             0.0             0.0             0.0  5703.000000        0.0
# mean              NaN             NaN             NaN    52.289523        NaN
# std               NaN             NaN             NaN    17.685820        NaN
# min               NaN             NaN             NaN     2.880000        NaN
# 25%               NaN             NaN             NaN    38.940000        NaN
# 50%               NaN             NaN             NaN    51.800000        NaN
# 75%               NaN             NaN             NaN    64.400000        NaN
# max               NaN             NaN             NaN   102.010000        NaN
#
#        Day Of Week ET
# count     6017.000000
# mean         3.020608
# std          1.999312
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max          6.000000
#
# [8 rows x 26 columns]

# %%
df.shape
# Out:
# (6017, 37)

# %%
df[df['snowdepth'].isna()].shape
# Out:
# (6017, 37)

# %%
df['skyc1'].value_counts()
# Out:
# skyc1
# CLR    2853
# OVC    1370
# SCT    1128
# BKN     656
# VV        2
# Name: count, dtype: int64

# %%
df.loc[30:50]
# Out:
#     id1  id2 station                      valid  tmpf  dwpf    relh   drct  \
# 30   30   62     JYO  2023-09-01 20:55:00+00:00  80.6  51.8   36.79    0.0
# 31   31   63     JYO  2023-09-01 21:15:00+00:00  80.6  50.0   34.41  140.0
# 32   32   64     JYO  2023-09-01 21:35:00+00:00  80.6  51.8   36.79  120.0
# 33   33   65     JYO  2023-09-01 21:55:00+00:00  80.6  50.0   34.41   70.0
# 34   34   66     JYO  2023-09-01 22:15:00+00:00  78.8  51.8   39.02  150.0
# 35   35   67     JYO  2023-09-01 22:35:00+00:00  78.8  50.0   36.51  130.0
# 36   36   68     JYO  2023-09-01 22:55:00+00:00  78.8  51.8   39.02  100.0
# 37   37   69     JYO  2023-09-01 23:15:00+00:00  78.8  51.8   39.02  120.0
# 38   38   70     JYO  2023-09-01 23:35:00+00:00  77.0  51.8   41.42  100.0
# 39   39  104     JYO  2023-09-02 10:55:00+00:00  55.4  53.6   93.65    0.0
# 40   40  105     JYO  2023-09-02 11:15:00+00:00  53.6  53.6  100.00    0.0
# 41   41  106     JYO  2023-09-02 11:35:00+00:00  55.4  53.6   93.65    0.0
# 42   42  107     JYO  2023-09-02 11:55:00+00:00  59.0  55.4   87.83    0.0
# 43   43  108     JYO  2023-09-02 12:15:00+00:00  60.8  55.4   82.37    0.0
# 44   44  109     JYO  2023-09-02 12:35:00+00:00  62.6  57.2   82.50    0.0
# 45   45  110     JYO  2023-09-02 12:55:00+00:00  64.4  57.2   77.45    0.0
# 46   46  111     JYO  2023-09-02 13:15:00+00:00  64.4  57.2   77.45    0.0
# 47   47  112     JYO  2023-09-02 13:35:00+00:00  68.0  59.0   72.92    0.0
# 48   48  113     JYO  2023-09-02 13:55:00+00:00  69.8  59.0   68.55  170.0
# 49   49  114     JYO  2023-09-02 14:15:00+00:00  71.6  59.0   64.48  250.0
# 50   50  115     JYO  2023-09-02 14:35:00+00:00  71.6  59.0   64.48  250.0
#
#     sknt  p01i  ...  peak_wind_drct  peak_wind_time   feel  \
# 30   0.0   0.0  ...             NaN             NaN  80.08
# 31   6.0   0.0  ...             NaN             NaN  79.88
# 32   5.0   0.0  ...             NaN             NaN  80.08
# 33   4.0   0.0  ...             NaN             NaN  79.88
# 34   5.0   0.0  ...             NaN             NaN  78.80
# 35   3.0   0.0  ...             NaN             NaN  78.80
# 36   3.0   0.0  ...             NaN             NaN  78.80
# 37   5.0   0.0  ...             NaN             NaN  78.80
# 38   3.0   0.0  ...             NaN             NaN  77.00
# 39   0.0   0.0  ...             NaN             NaN  55.40
# 40   0.0   0.0  ...             NaN             NaN  53.60
# 41   0.0   0.0  ...             NaN             NaN  55.40
# 42   0.0   0.0  ...             NaN             NaN  59.00
# 43   0.0   0.0  ...             NaN             NaN  60.80
# 44   0.0   0.0  ...             NaN             NaN  62.60
# 45   0.0   0.0  ...             NaN             NaN  64.40
# 46   0.0   0.0  ...             NaN             NaN  64.40
# 47   0.0   0.0  ...             NaN             NaN  68.00
# 48   4.0   0.0  ...             NaN             NaN  69.80
# 49   3.0   0.0  ...             NaN             NaN  71.60
# 50   3.0   0.0  ...             NaN             NaN  71.60
#
#                                                 metar snowdepth  \
# 30  KJYO 012055Z AUTO 00000KT 10SM CLR 27/11 A3025...       NaN
# 31  KJYO 012115Z AUTO 14006KT 10SM CLR 27/10 A3024...       NaN
# 32  KJYO 012135Z AUTO 12005KT 10SM CLR 27/11 A3024...       NaN
# 33  KJYO 012155Z AUTO 07004KT 10SM CLR 27/10 A3024...       NaN
# 34  KJYO 012215Z AUTO 15005KT 10SM CLR 26/11 A3024...       NaN
# 35  KJYO 012235Z AUTO 13003KT 10SM CLR 26/10 A3024...       NaN
# 36  KJYO 012255Z AUTO 10003KT 10SM CLR 26/11 A3024...       NaN
# 37  KJYO 012315Z AUTO 12005KT 10SM CLR 26/11 A3023...       NaN
# 38  KJYO 012335Z AUTO 10003KT 10SM CLR 25/11 A3024...       NaN
# 39  KJYO 021055Z AUTO 00000KT 10SM CLR 13/12 A3026...       NaN
# 40  KJYO 021115Z AUTO 00000KT 10SM CLR 12/12 A3026...       NaN
# 41  KJYO 021135Z AUTO 00000KT 10SM CLR 13/12 A3027...       NaN
# 42  KJYO 021155Z AUTO 00000KT 10SM CLR 15/13 A3027...       NaN
# 43  KJYO 021215Z AUTO 00000KT 10SM CLR 16/13 A3027...       NaN
# 44  KJYO 021235Z AUTO 00000KT 10SM CLR 17/14 A3027...       NaN
# 45  KJYO 021255Z AUTO 00000KT 10SM CLR 18/14 A3027...       NaN
# 46  KJYO 021315Z AUTO 00000KT 10SM CLR 18/14 A3026...       NaN
# 47  KJYO 021335Z AUTO 00000KT 10SM CLR 20/15 A3026...       NaN
# 48  KJYO 021355Z AUTO 17004KT 10SM CLR 21/15 A3026...       NaN
# 49  KJYO 021415Z AUTO 25003KT 10SM CLR 22/15 A3026...       NaN
# 50  KJYO 021435Z AUTO 25003KT 10SM CLR 22/15 A3026...       NaN
#
#                      valid_ET Day Of Week ET  \
# 30  2023-09-01 16:55:00-04:00              4
# 31  2023-09-01 17:15:00-04:00              4
# 32  2023-09-01 17:35:00-04:00              4
# 33  2023-09-01 17:55:00-04:00              4
# 34  2023-09-01 18:15:00-04:00              4
# 35  2023-09-01 18:35:00-04:00              4
# 36  2023-09-01 18:55:00-04:00              4
# 37  2023-09-01 19:15:00-04:00              4
# 38  2023-09-01 19:35:00-04:00              4
# 39  2023-09-02 06:55:00-04:00              5
# 40  2023-09-02 07:15:00-04:00              5
# 41  2023-09-02 07:35:00-04:00              5
# 42  2023-09-02 07:55:00-04:00              5
# 43  2023-09-02 08:15:00-04:00              5
# 44  2023-09-02 08:35:00-04:00              5
# 45  2023-09-02 08:55:00-04:00              5
# 46  2023-09-02 09:15:00-04:00              5
# 47  2023-09-02 09:35:00-04:00              5
# 48  2023-09-02 09:55:00-04:00              5
# 49  2023-09-02 10:15:00-04:00              5
# 50  2023-09-02 10:35:00-04:00              5
#
#                              sunrise                            sunset  \
# 30  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 31  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 32  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 33  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 34  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 35  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 36  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 37  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 38  2023-09-01 10:37:07.576681+00:00  2023-09-01 23:38:34.757806+00:00
# 39  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 40  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 41  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 42  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 43  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 44  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 45  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 46  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 47  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 48  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 49  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
# 50  2023-09-02 10:38:01.238896+00:00  2023-09-02 23:37:02.770575+00:00
#
#     daylight
# 30      True
# 31      True
# 32      True
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39      True
# 40      True
# 41      True
# 42      True
# 43      True
# 44      True
# 45      True
# 46      True
# 47      True
# 48      True
# 49      True
# 50      True
#
# [21 rows x 37 columns]

# %%
df[(df['skyc1']=='CLR')].shape
# Out:
# (2853, 37)

# %%
df[(df['skyc1']=='CLR') & (df['p01i']>0)].shape
# Out:
# (16, 37)

# %%
df[df['p01i']>0].shape[0] / df[df['p01i']>=0].shape[0]
# Out:
# 0.038557420641515704

# %%
for c in ['skyc1', 'skyc2', 'skyc3', 'skyc4']:
	print(c,df[df[c].isna()].shape)
# Out:
# skyc1 (8, 37)
# skyc2 (5017, 37)
# skyc3 (5692, 37)
# skyc4 (6017, 37)

# %%
df[(df['skyc1'] != df['skyc2']) & (df['skyc1']=='CLR')][['skyc1','skyc2']]
# Out:
#      skyc1 skyc2
# 0      CLR   NaN
# 1      CLR   NaN
# 2      CLR   NaN
# 3      CLR   NaN
# 4      CLR   NaN
# ...    ...   ...
# 5976   CLR   NaN
# 5978   CLR   NaN
# 5979   CLR   NaN
# 5980   CLR   NaN
# 5981   CLR   NaN
#
# [2853 rows x 2 columns]

# %%
df[(df['skyc1'] != df['skyc2'])][['skyc1','skyc2']].value_counts()
# Out:
# skyc1  skyc2
# BKN    OVC      225
# SCT    BKN      214
#        OVC      207
# Name: count, dtype: int64

# %%
total_p01i_per_day_et_new = df.groupby('Day Of Week ET')['p01i'].sum()

# %%
total_p01i_per_day_et_new
# Out:
# Day Of Week ET
# 0    0.30
# 1    5.15
# 2    0.67
# 3    0.41
# 4    0.58
# 5    7.28
# 6    0.16
# Name: p01i, dtype: float64

# %% [markdown]
# We would like to count the number of clear observations per day. We can do this with a `groupby` followed by a `size()` function

# %%
df[df['skyc1'] == 'CLR'].groupby('Day Of Week ET').size()
# Out:
# Day Of Week ET
# 0    385
# 1    362
# 2    431
# 3    516
# 4    489
# 5    341
# 6    329
# dtype: int64

# %%
df[df['skyc1'] == 'CLR'].groupby('Day Of Week ET').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Day Of Week ET'>

# %% [markdown]
# Does every day have the same number of recorded observations?

# %%
df.groupby('Day Of Week ET').size().plot(kind="bar")
# Out:
# <Axes: xlabel='Day Of Week ET'>

# %%
percentage_clr_days_et_new = (df[df['skyc1'] == 'CLR'].groupby('Day Of Week ET').size() / df.groupby('Day Of Week ET').size()) * 100

# %%
percentage_clr_days_et_new
# Out:
# Day Of Week ET
# 0    45.187793
# 1    42.688679
# 2    50.705882
# 3    61.355529
# 4    55.379388
# 5    38.487585
# 6    38.389732
# dtype: float64

# %%
percentage_clr_days_et_new.plot(kind='bar')
# Out:
# <Axes: xlabel='Day Of Week ET'>

# %% [markdown]
# Conclusions? BTW what is day 5 and 6? How else could you define a good/bad day? What ways could you change the question to make your desired outcome more likely? Is this statistically significant?
